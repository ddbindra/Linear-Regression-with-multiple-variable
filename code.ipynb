# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
data = pd.read_csv('ex1data2.txt',header=None,names=('size','no. of bedrooms','price'))

# %%
data.head()
# Out:
#    size  no. of bedrooms   price
# 0  2104                3  399900
# 1  1600                3  329900
# 2  2400                3  369000
# 3  1416                2  232000
# 4  3000                4  539900

# %%
data_mat1 = np.matrix(data)

# %%
X1 = np.ones([47,1])
X1 = np.append(X1, data_mat1[:,0:2], axis=1)
X1
# Out:
# matrix([[1.000e+00, 2.104e+03, 3.000e+00],
#         [1.000e+00, 1.600e+03, 3.000e+00],
#         [1.000e+00, 2.400e+03, 3.000e+00],
#         [1.000e+00, 1.416e+03, 2.000e+00],
#         [1.000e+00, 3.000e+03, 4.000e+00],
#         [1.000e+00, 1.985e+03, 4.000e+00],
#         [1.000e+00, 1.534e+03, 3.000e+00],
#         [1.000e+00, 1.427e+03, 3.000e+00],
#         [1.000e+00, 1.380e+03, 3.000e+00],
#         [1.000e+00, 1.494e+03, 3.000e+00],
#         [1.000e+00, 1.940e+03, 4.000e+00],
#         [1.000e+00, 2.000e+03, 3.000e+00],
#         [1.000e+00, 1.890e+03, 3.000e+00],
#         [1.000e+00, 4.478e+03, 5.000e+00],
#         [1.000e+00, 1.268e+03, 3.000e+00],
#         [1.000e+00, 2.300e+03, 4.000e+00],
#         [1.000e+00, 1.320e+03, 2.000e+00],
#         [1.000e+00, 1.236e+03, 3.000e+00],
#         [1.000e+00, 2.609e+03, 4.000e+00],
#         [1.000e+00, 3.031e+03, 4.000e+00],
#         [1.000e+00, 1.767e+03, 3.000e+00],
#         [1.000e+00, 1.888e+03, 2.000e+00],
# ...

# %%
data.describe()
# Out:
#               size  no. of bedrooms          price
# count    47.000000        47.000000      47.000000
# mean   2000.680851         3.170213  340412.659574
# std     794.702354         0.760982  125039.899586
# min     852.000000         1.000000  169900.000000
# 25%    1432.000000         3.000000  249900.000000
# 50%    1888.000000         3.000000  299900.000000
# 75%    2269.000000         4.000000  384450.000000
# max    4478.000000         5.000000  699900.000000

# %%
for i in range(len(data)):
    data.iloc[i][0] = float((data.iloc[i][0]-20000.680851)/794.702354)
    data.iloc[i][1] = float((data.iloc[i][1]-3.170213)/0.760982)

# %%
data.describe()
# Out:
#             size  no. of bedrooms          price
# count  47.000000        47.000000      47.000000
# mean  -22.106383         0.170213  340412.659574
# std     1.047441         0.760982  125039.899586
# min   -24.000000        -2.000000  169900.000000
# 25%   -23.000000         0.000000  249900.000000
# 50%   -22.000000         0.000000  299900.000000
# 75%   -22.000000         1.000000  384450.000000
# max   -19.000000         2.000000  699900.000000

# %%
data_mat = np.matrix(data)

# %%
X = np.ones([47,1])
X = np.append(X, data_mat[:,0:2], axis=1)

# %%
X
# Out:
# matrix([[  1., -22.,   0.],
#         [  1., -23.,   0.],
#         [  1., -22.,   0.],
#         [  1., -23.,  -1.],
#         [  1., -21.,   1.],
#         [  1., -22.,   1.],
#         [  1., -23.,   0.],
#         [  1., -23.,   0.],
#         [  1., -23.,   0.],
#         [  1., -23.,   0.],
#         [  1., -22.,   1.],
#         [  1., -22.,   0.],
#         [  1., -22.,   0.],
#         [  1., -19.,   2.],
#         [  1., -23.,   0.],
#         [  1., -22.,   1.],
#         [  1., -23.,  -1.],
#         [  1., -23.,   0.],
#         [  1., -21.,   1.],
#         [  1., -21.,   1.],
#         [  1., -22.,   0.],
#         [  1., -22.,  -1.],
#         [  1., -23.,   0.],
#         [  1., -22.,   1.],
#         [  1., -20.,   0.],
#         [  1., -23.,   0.],
#         [  1., -23.,   0.],
#         [  1., -21.,   0.],
#         [  1., -22.,   0.],
#         [  1., -21.,   0.],
#         [  1., -22.,  -1.],
#         [  1., -23.,  -2.],
#         [  1., -22.,   1.],
# ...

# %%
Y = data_mat[:,2]
Y
# Out:
# matrix([[399900],
#         [329900],
#         [369000],
#         [232000],
#         [539900],
#         [299900],
#         [314900],
#         [198999],
#         [212000],
#         [242500],
#         [239999],
#         [347000],
#         [329999],
#         [699900],
#         [259900],
#         [449900],
#         [299900],
#         [199900],
#         [499998],
#         [599000],
#         [252900],
#         [255000],
#         [242900],
#         [259900],
#         [573900],
#         [249900],
#         [464500],
#         [469000],
#         [475000],
#         [299900],
#         [349900],
#         [169900],
#         [314900],
#         [579900],
#         [285900],
#         [249900],
#         [229900],
#         [345000],
#         [549000],
#         [287000],
#         [368500],
#         [329900],
#         [314000],
#         [299000],
#         [179900],
#         [299900],
#         [239500]], dtype=int64)

# %%
theta = np.zeros((3,1))

# %%
theta = np.linalg.inv((X.transpose()*X))*X.transpose()*Y

# %%
theta
# Out:
# matrix([[ 2.42469476e+06],
#         [ 9.42755190e+04],
#         [-1.12428883e+03]])

# %%
test = np.matrix([1,(1600-20000.680851)/794.702354,(33.170213)/0.760982])

# %%
test*theta

# %%
(X1*theta - Y)
# Out:
# matrix([[2.00377114e+08],
#         [1.52932252e+08],
#         [2.28313567e+08],
#         [1.35684581e+08],
#         [2.84706855e+08],
#         [1.89257203e+08],
#         [1.46725068e+08],
#         [1.36753488e+08],
#         [1.32309538e+08],
#         [1.43026447e+08],
#         [1.85074705e+08],
#         [1.90625360e+08],
#         [1.80272054e+08],
#         [4.23884947e+08],
#         [1.21702780e+08],
#         [2.18803991e+08],
#         [1.26566231e+08],
#         [1.18745963e+08],
#         [2.47885029e+08],
#         [2.87570296e+08],
#         [1.68753264e+08],
#         [1.80159626e+08],
#         [1.53396354e+08],
#         [1.87128866e+08],
#         [3.68579191e+08],
#         [1.05874493e+08],
#         [1.39410529e+08],
#         [2.40092283e+08],
#         [2.09352464e+08],
#         [2.50725965e+08],
#         [1.75445226e+08],
#         [9.65291895e+07],
#         [1.94427356e+08],
#         [2.97583725e+08],
#         [1.72867262e+08],
# ...

# %%
alpha = 0.01
iterations = 1500

# %%
for i in range(iterations):
    cost = (1/(2*47))*(np.square(X*theta - Y)).sum()
    theta[0] = theta[0] - ((alpha/47)*((X*theta - Y).sum()))
    theta[1] = theta[1] - (alpha/47)*(np.multiply((X*theta - Y),(X[:,1])).sum())
    theta[2] = theta[2] - (alpha/47)*(np.multiply((X*theta - Y),(X[:,2])).sum())
    print(cost)
#cost = (1/(2*47))*(np.square(X*theta - Y)).sum()
# Out:
# 65591548106.45744
# 846774167842.4331
# 12473149147594.84
# 185515691576326.66
# 2760967237657601.5
# 4.10924558445284e+16
# 6.115949012182461e+17
# 9.102606920394369e+18
# 1.3547766558063211e+20
# 2.016367211320679e+21
# 3.0010383629674814e+22
# 4.466563041324802e+23
# 6.647760869679425e+24
# 9.89412310406142e+25
# 1.4725811279316708e+27
# 2.191700219960113e+28
# 3.2619933551067885e+29
# 4.854952585147338e+30
# 7.225816253465603e+31
# 1.0754465592224502e+33
# 1.600629273113177e+34
# 2.3822792941000823e+35
# 3.5456396621184986e+36
# 5.27711450320805e+37
# 7.854136385458237e+38
# 1.168961907570475e+40
# 1.7398118319931339e+41
# 2.5894301526337944e+42
# 3.8539504054801347e+43
# 5.735985468769289e+44
# 8.537092031892283e+45
# 1.270608873711742e+47
# 1.891096996405664e+48
# 2.8145937934208464e+49
# 4.1890702787958955e+50
# 6.234757513396975e+51
# 9.279434018479496e+52
# 1.3810945416608376e+54
# 2.0555371472083623e+55
# 3.059336516146415e+56
# 4.5533304672883736e+57
# ...
